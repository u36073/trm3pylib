# %%
# Plot a complex chart with intearctive hover in a few lines of code
from bokeh.io import output_notebook, show
output_notebook()
from bokeh.models import ColumnDataSource, HoverTool
from bokeh.plotting import figure
from bokeh.sampledata.autompg import autompg_clean as df
from bokeh.transform import factor_cmap

df.cyl = df.cyl.astype(str)
df.yr = df.yr.astype(str)

group = df.groupby(('cyl', 'mfr'))
source = ColumnDataSource(group)

p = figure(plot_width=1600, plot_height=600, title="Mean MPG by # Cylinders and Manufacturer",
           x_range=group, toolbar_location=None, tools="")

p.xgrid.grid_line_color = None
p.xaxis.axis_label = "Manufacturer grouped by # Cylinders"
p.xaxis.major_label_orientation = 1.2

index_cmap = factor_cmap('cyl_mfr', palette=['#2b83ba', '#abdda4', '#ffffbf', '#fdae61', '#d7191c'], 
                         factors=sorted(df.cyl.unique()), end=1)

p.vbar(x='cyl_mfr', top='mpg_mean', width=1, source=source,
       line_color="white", fill_color=index_cmap, 
       hover_line_color="black", hover_fill_color=index_cmap)

p.add_tools(HoverTool(tooltips=[("MPG", "@mpg_mean"), ("Cyl, Mfr", "@cyl_mfr")]))

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="4c4e4beb-700f-4a84-b0de-fc0f12c46d34">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="faaa24ed-2f28-4261-bbb8-6f4d04a8e55f"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("faaa24ed-2f28-4261-bbb8-6f4d04a8e55f");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("faaa24ed-2f28-4261-bbb8-6f4d04a8e55f");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'faaa24ed-2f28-4261-bbb8-6f4d04a8e55f' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"4507293d-c2e7-43d7-8545-e7d1de3329c2":{"roots":{"references":[{"attributes":{},"id":"4b6cd8bd-47af-46b7-8a83-406c9ec367d9","type":"CategoricalTickFormatter"},{"attributes":{"fill_color":{"field":"cyl_mfr","transform":{"id":"2f9d9584-e8bf-4bed-a68b-7c8068a61252","type":"CategoricalColorMapper"}},"line_color":{"value":"white"},"top":{"field":"mpg_mean"},"width":{"value":1},"x":{"field":"cyl_mfr"}},"id":"4778a04c-f703-4de6-8de0-890fea2a542a","type":"VBar"},{"attributes":{"grid_line_color":{"value":null},"plot":{"id":"780c436a-8f3e-4a00-a06e-39819d926b45","subtype":"Figure","type":"Plot"},"ticker":{"id":"4aad3172-a9d2-43c5-9181-a3f30a8b5d4e","type":"CategoricalTicker"}},"id":"bc4b6631-9293-43a0-aa38-2e6740cbaf56","type":"Grid"},{"attributes":{"data_source":{"id":"13612188-7c72-478a-83f0-30195b46e08e","type":"ColumnDataSource"},"glyph":{"id":"4778a04c-f703-4de6-8de0-890fea2a542a","type":"VBar"},"hover_glyph":{"id":"a39bb8eb-8e10-4d77-b1b4-c73e01b6eb72","type":"VBar"},"muted_glyph":null,"nonselection_glyph":{"id":"a29f1fda-8633-41a4-b70c-2c566560f488","type":"VBar"},"selection_glyph":null,"view":{"id":"750c73a2-7998-43a0-9800-2bb0112de754","type":"CDSView"}},"id":"6109bbd8-b032-473b-a519-15ce9e1b109b","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":
# 381  38.0   6  262.0   85    3015   17.0  82  North America
# 382  26.0   4  156.0   92    2585   14.5  82  North America
# 383  22.0   6  232.0  112    2835   14.7  82  North America
# 384  32.0   4  144.0   96    2665   13.9  82           Asia
# 385  36.0   4  135.0   84    2370   13.0  82  North America
# 386  27.0   4  151.0   90    2950   17.3  82  North America
# 387  27.0   4  140.0   86    2790   15.6  82  North America
# 388  44.0   4   97.0   52    2130   24.6  82         Europe
# 389  32.0   4  135.0   84    2295   11.6  82  North America
# 390  28.0   4  120.0   79    2625   18.6  82  North America
# 391  31.0   4  119.0   82    2720   19.4  82  North America
#
#                                   name         mfr
# 0            chevrolet chevelle malibu   chevrolet
# 1                    buick skylark 320       buick
# 2                   plymouth satellite    plymouth
# 3                        amc rebel sst         amc
# 4                          ford torino        ford
# 5                     ford galaxie 500        ford
# 6                     chevrolet impala   chevrolet
# 7                    plymouth fury iii    plymouth
# 8                     pontiac catalina     pontiac
# 9                   amc ambassador dpl         amc
# 10                 dodge challenger se       dodge
# 11                  plymouth 'cuda 340    plymouth
# 12               chevrolet monte carlo   chevrolet
# 13             buick estate wagon (sw)       buick
# 14               toyota corona mark ii      toyota
# 15                     plymouth duster    plymouth
# 16                          amc hornet         amc
# 17                       ford maverick        ford
# 18                        datsun pl510      datsun
# 19        volkswagen 1131 deluxe sedan  volkswagen
# 20                         peugeot 504     peugeot
# 21                         audi 100 ls        audi
# 22                            saab 99e        saab
# 23                            bmw 2002         bmw
# 24                         amc gremlin         amc
# 25                           ford f250        ford
# 26                           chevy c20   chevrolet
# 27                          dodge d200       dodge
# 28                            hi 1200d          hi
# 29                        datsun pl510      datsun
# ..                                 ...         ...
# 362                 chevrolet cavalier   chevrolet
# 363           chevrolet cavalier wagon   chevrolet
# 364          chevrolet cavalier 2-door   chevrolet
# 365         pontiac j2000 se hatchback     pontiac
# 366                     dodge aries se       dodge
# 367                    pontiac phoenix     pontiac
# 368               ford fairmont futura        ford
# 369                volkswagen rabbit l  volkswagen
# 370                 mazda glc custom l       mazda
# 371                   mazda glc custom       mazda
# 372             plymouth horizon miser    plymouth
# 373                     mercury lynx l     mercury
# 374                   nissan stanza xe      nissan
# 375                       honda accord       honda
# 376                     toyota corolla      toyota
# 377                        honda civic       honda
# 378                 honda civic (auto)       honda
# 379                      datsun 310 gx      datsun
# 380              buick century limited       buick
# 381  oldsmobile cutlass ciera (diesel)  oldsmobile
# 382         chrysler lebaron medallion    chrysler
# 383                     ford granada l        ford
# 384                   toyota celica gt      toyota
# 385                  dodge charger 2.2       dodge
# 386                   chevrolet camaro   chevrolet
# 387                    ford mustang gl        ford
# 388                          vw pickup  volkswagen
# 389                      dodge rampage       dodge
# 390                        ford ranger        ford
# 391                         chevy s-10   chevrolet
#
# [392 rows x 10 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-943269dcc227> in <module>()
# ----> 1 mpg_mean
#
# NameError: name 'mpg_mean' is not defined
